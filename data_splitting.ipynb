# %%
import pandas as pd
from sklearn.model_selection import train_test_split

df = pd.read_csv("train.csv")

# %%
x = df.drop(columns=["SalePrice"])
y = df["SalePrice"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

print(f"Original dataset shape: {df.shape}")
print(f"X_train shape (The Textbook): {x_train.shape}")
print(f"X_test shape (The Final Exam): {x_test.shape}")
# Out:
# Original dataset shape: (1460, 81)
# X_train shape (The Textbook): (1168, 80)
# X_test shape (The Final Exam): (292, 80)

# %% [markdown]
# Splitting the data to avoid data leakage
